# %% [markdown]
# # X. Model Inference

# %% [markdown]
# > Model yang sudah dilatih akan dicoba pada data yang bukan termasuk ke dalam train-set, val-set, ataupun test-set. Data ini harus dalam format yang asli, bukan data yang sudah di-scaled. Model Inference harus berada pada notebook yang berbeda dari notebook yang dipakai untuk pembuatan model.

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

print('Berhasil Mengimport Libraries')
# Out:
# Berhasil Mengimport Libraries

# %%
# !powershell Invoke-WebRequest -Uri "https://assets.pikiran-rakyat.com/crop/0x0:0x0/750x500/photo/2023/02/05/972918958.jpg" -OutFile "img/image1.jpg"

# %%
# !powershell Invoke-WebRequest -Uri "https://asset-a.grid.id/crop/0x0:0x0/700x465/photo/2021/08/25/menjulurkan-lidahjpg-20210825050556.jpg" -OutFile "img/image2.jpg"

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

loaded_model = load_model('model1.h5')

img_path = 'img/image1.jpg'
img = image.load_img(img_path, target_size=(224, 224))  
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  

predictions = loaded_model.predict(img_array)

model_pred_final = np.where(predictions >= 0.35, 1, 0)

plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('cats' if model_pred_final[0][0] == 0 else 'dogs'))
# Out:
# 1/1 [==============================] - 0s 278ms/step
# Prediction is a cats

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

loaded_model = load_model('model1.h5')

img_path = 'img/image2.jpg'
img = image.load_img(img_path, target_size=(224, 224))  
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  

predictions = loaded_model.predict(img_array)

model_pred_final = np.where(predictions >= 0.35, 1, 0)

plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('cats' if model_pred_final[0][0] == 0 else 'dogs'))
# Out:
# 1/1 [==============================] - 0s 268ms/step
# Prediction is a dogs
